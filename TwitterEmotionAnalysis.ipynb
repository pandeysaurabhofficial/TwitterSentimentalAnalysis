# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob 

class TwitterClient(object): 
    def __init__(self): 
        # keys and tokens from the Twitter Dev Console 
        consumer_key = 'ITtwYxAL1dHtU5oV5X4ajZ9Uf'
        consumer_secret = 'jVx8JgueA6MhNjpZe1JzyjJqQj3tUwwOYxQ8dhcilZa8srTRgA'
        access_token = '1086713156817354752-kqSg6Hbv3zIHgzL2gpu1Ax4jbJOITA'
        access_token_secret = 'gFzDA9KJFXDOLHCGDJXW9Ovly89XhK5ZVMTmKaEVIv9Wn'

# attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 

    def clean_tweet(self, tweet): 

        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)", " ", tweet).split()) 

    def get_tweet_sentiment(self, tweet): 

        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

    def get_tweets(self, query, count = 10): 

        # empty list to store parsed tweets 
        tweets = [] 

        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q = query, count = count) 
            
            # parsing tweets one by one 
            for tweet in fetched_tweets: 
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
                
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
                
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0: 
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
                    
                # return parsed tweets 
            return tweets 

        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e)) 

def main(): 
    # creating object of TwitterClient Class 
    api = TwitterClient() 
    # calling function to get tweets 
    tweets = api.get_tweets(query = 'Modi', count = 200) 
    
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} % \ ".format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets))) 

    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 

    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 

if __name__ == "__main__": 
    # calling main function 
    main()
# Out:
# Positive tweets percentage: 28.235294117647058 %
# Negative tweets percentage: 9.411764705882353 %
# Neutral tweets percentage: 62.35294117647059 % \
#
#
# Positive tweets:
# RT @ShashiTharoor: As #Rafale joins @IAF_MCC, a few reminders: 1. UPA selected #Rafale &amp;inked the first deal for 126 aircraft
# 2. Modi govt…
# RT @INCTelangana: Notes reveal PMO undermined negotiations made by MoD.
#
# PMO/Modi ji had acted as a middleman for bankrupt industrialist An…
# @RepJerryNadler IAM THE EMPEROR OF BRITISH EAST INDIA COMPANY MY GRAND SIRE SRI KRISHNA INCORPORATED BRITISH UNION… https://t.co/J1X5KhJfPz
# @DrKumarVishwas Modi ji ki dream smart city
# @sanjukta Now we are Sure that we have to vote for BJP and Modi
# @one_by_two No need to get worried about. Modi will win in 2024.
# Please open our colleges modi JI we are done with staying at home with non supportive family. For some it’s a pleas… https://t.co/h1TnJzuotE
# Lol anyone who doesn’t support her is anti national now. Itna toh Modi ji bhi aage nahi gaye 😂😂😂 https://t.co/WM2NrDbNy5
# RT @imMAK02: Modi's lapdog BC @bhupendrachaube showing his hypocrisy.
#
# Pic 1: Demanded legal action against #tablighiJamaat .
#
# Pic 2 : No a…
# RT @Roy__aashish: Yes, Modi is killing innocent terrorist.
# #मुसलमान_पर_अत्याचार_बंद_करो https://t.co/ysbID2HCLy
#
#
# Negative tweets:
# @haryannvi At least this policy misses the 99% not 1%.
#
# You are dividing the nation. May lead to violent separatist… https://t.co/CTnQMp5plh
# RT @Subytweets: Hope #Rafale will strengthen Modi's Spine and make him say China, at least! https://t.co/DMsNc8ZcdK
# RT @maheshsabane1: #मुसलमान_पर_अत्याचार_बंद_करो Don't bring Modi in every aspects its just 6 years he is in power,but you hate hindus from…
# RT @Robinho34084784: @SrishtaS They are devoid of any logic . Kuchh naa Mila too Modi Modi , Bhakt Bhakt bas yahi AATA hai inko
# RT @Shubhi80476007: @KanganaOffical @TimesNow If Aditya Thakre's name is coming up now, Modi will not take any other second &amp; will definite…
# RT @Ramakant_2002: @TIinExile Everyday a leftist , a congressi , an Islamist propagate a myth , a lie and everyday @TIinExile burst that my…
# RT @ashoswai: Modi regime's arrest of Delhi University Professor Hany Babu shows there is no academic freedom in India. No education policy…
# @FreeTib36358389 @FrontalAssault1 That's what congi motherfuckers were doing in the past, making India a soft power… https://t.co/d1u2SR98Jd
